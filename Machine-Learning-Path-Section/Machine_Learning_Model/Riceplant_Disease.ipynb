# %%
# !pip install split-folders
import tensorflow as tf
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import Model
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt 

import zipfile,os
import splitfolders
import numpy as np
from google.colab import files
from keras.preprocessing import image
import keras
import shutil
# Out:
# Requirement already satisfied: split-folders in /usr/local/lib/python3.7/dist-packages (0.4.3)

# %% [markdown]
# ## Download Rice leaf Disease Dataset from Kaggle

# %%
! chmod 600 kaggle.json && (ls ~/.kaggle 2>/dev/null || mkdir ~/.kaggle) && mv kaggle.json ~/.kaggle/ && echo 'Done'
# Out:
# chmod: cannot access 'kaggle.json': No such file or directory

# %%
! kaggle datasets download vbookshelf/rice-leaf-diseases
# Out:
# rice-leaf-diseases.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
local_zip = '/content/rice-leaf-diseases.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/content')
zip_ref.close()

# %%
os.listdir("/content/rice_leaf_diseases")
# Out:
# ['Bacterial leaf blight', 'Brown spot', 'Leaf smut']

# %%
root_dir = '/content/rice_leaf_diseases' # data root path
classes_dir = ['Bacterial leaf blight', 'Brown spot', 'Leaf smut'] #total labels

val_ratio = 0.2
test_ratio = 0.2

total_data = 0
total_train_data = 0 
total_validation_data = 0
total_test_data = 0
for cls in classes_dir:
    os.makedirs(root_dir +'_train/' + cls)
    os.makedirs(root_dir +'_val/' + cls)
    os.makedirs(root_dir +'_test/' + cls)


  # Creating partitions of the data after shuffeling
    src = root_dir + '/' + cls # Folder to copy images from

    allFileNames = os.listdir(src)
    print(src)
    np.random.shuffle(allFileNames)
    train_FileNames, val_FileNames, test_FileNames = np.split(np.array(allFileNames),
                                                              [int(len(allFileNames)* (1 - (val_ratio + test_ratio))), 
                                                              int(len(allFileNames)* (1 - test_ratio))])


    train_FileNames = [src+'/'+ name for name in train_FileNames.tolist()]
    val_FileNames = [src+'/' + name for name in val_FileNames.tolist()]
    test_FileNames = [src+'/' + name for name in test_FileNames.tolist()]

    # Copy-pasting images
    for name in train_FileNames:
        shutil.copy(name, root_dir +'_train/' + cls)

    for name in val_FileNames:
        shutil.copy(name, root_dir +'_val/' + cls)

    for name in test_FileNames:
        shutil.copy(name, root_dir +'_test/' + cls)

    #count total images
    total_data += len(allFileNames)
    total_train_data += len(train_FileNames)
    total_validation_data += len(val_FileNames)
    total_test_data += len(test_FileNames)


print('Total images: ', total_data)
print('Training: ', total_train_data)
print('Validation: ', total_validation_data)
print('Testing: ', total_test_data)
# Out:
# /content/rice_leaf_diseases/Bacterial leaf blight
# /content/rice_leaf_diseases/Brown spot
# /content/rice_leaf_diseases/Leaf smut
# Total images:  120
# Training:  72
# Validation:  24
# Testing:  24

# %%
# !rm -rf rice_leaf_diseases_train
# !rm -rf rice_leaf_diseases_val
# !rm -rf rice_leaf_diseases_test

# %% [markdown]
# ## Augmentasi Gambar

# %%
train_datagen = ImageDataGenerator(
                    rescale=1./255,
                    rotation_range=20,
                    horizontal_flip=True,
                    shear_range = 0.2,
                    validation_split = 0.4,
                    fill_mode = 'nearest')

val_datagen = ImageDataGenerator(
                    rescale=1./255)

test_datagen = ImageDataGenerator(
                    rescale=1./255)

# %%
train_dir = "/content/rice_leaf_diseases_train"
validation_dir = "/content/rice_leaf_diseases_val"
testing_dir = "/content/rice_leaf_diseases_test"

train_generator = train_datagen.flow_from_directory(
        train_dir,  
        target_size=(150, 150),  
        batch_size=4,
        class_mode='categorical') 
        
 
validation_generator = val_datagen.flow_from_directory(
        validation_dir, 
        target_size=(150, 150), 
        batch_size=4, 
        class_mode='categorical')
        
 
testing_generator = test_datagen.flow_from_directory(
        testing_dir, 
        target_size=(150, 150), 
        batch_size=4, 
        class_mode='categorical')
# Out:
# Found 72 images belonging to 3 classes.
# Found 24 images belonging to 3 classes.
# Found 24 images belonging to 3 classes.

# %% [markdown]
# # MobileNetV2

# %%
from keras.applications.mobilenet_v2 import MobileNetV2

# %%
model = keras.models.Sequential()
model.add(MobileNetV2(weights='imagenet',include_top=False,input_shape=(150,150,3)))
model.add(tf.keras.layers.Conv2D(256, (3,3), activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(2,2))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(521, activation='relu'))
model.add(tf.keras.layers.Dense(3, activation='softmax'))
model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenetv2_1.00_224 (Functi (None, 5, 5, 1280)        2257984
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 3, 256)         2949376
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 521)               133897
# _________________________________________________________________
# dense_7 (Dense)              (None, 3)                 1566
# =================================================================
# Total params: 5,342,823
# Trainable params: 5,308,711
# Non-trainable params: 34,112
# _________________________________________________________________

# %% [markdown]
# ## Compile Model

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=tf.optimizers.Adam(),
              metrics=['accuracy'])

# %%
class CustomCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy')>0.97):
      print("Akurasi Diatas 97%")
      self.model.stop_training = True

# %%
history = model.fit(
      train_generator,
      steps_per_epoch=30,  
      epochs=50,
      validation_data=validation_generator, 
      validation_steps=4,
      callbacks=[CustomCallback()],  
     )
# Out:
# Epoch 1/50
# 30/30 [==============================] - 9s 300ms/step - loss: 1.1278 - accuracy: 0.4500 - val_loss: 8.7815 - val_accuracy: 0.5000
# Epoch 2/50
# 30/30 [==============================] - 9s 298ms/step - loss: 1.0485 - accuracy: 0.4167 - val_loss: 8.4063 - val_accuracy: 0.3750
# Epoch 3/50
# 30/30 [==============================] - 9s 295ms/step - loss: 1.0936 - accuracy: 0.4667 - val_loss: 3.2750 - val_accuracy: 0.5000
# Epoch 4/50
# 30/30 [==============================] - 9s 300ms/step - loss: 1.1485 - accuracy: 0.4167 - val_loss: 3.7114 - val_accuracy: 0.2500
# Epoch 5/50
# 30/30 [==============================] - 9s 297ms/step - loss: 1.2264 - accuracy: 0.3833 - val_loss: 1.6413 - val_accuracy: 0.7500
# Epoch 6/50
# 30/30 [==============================] - 9s 295ms/step - loss: 1.2049 - accuracy: 0.4500 - val_loss: 30.0406 - val_accuracy: 0.3750
# Epoch 7/50
# 30/30 [==============================] - 9s 298ms/step - loss: 2.0068 - accuracy: 0.4167 - val_loss: 30.6490 - val_accuracy: 0.3750
# Epoch 8/50
# 30/30 [==============================] - 9s 295ms/step - loss: 1.1145 - accuracy: 0.3167 - val_loss: 39.7030 - val_accuracy: 0.5000
# Epoch 9/50
# 30/30 [==============================] - 9s 296ms/step - loss: 1.2144 - accuracy: 0.3833 - val_loss: 36.9501 - val_accuracy: 0.3750
# Epoch 10/50
# 30/30 [==============================] - 9s 295ms/step - loss: 1.1067 - accuracy: 0.3833 - val_loss: 38.9190 - val_accuracy: 0.3750
# Epoch 11/50
# 30/30 [==============================] - 9s 296ms/step - loss: 1.0901 - accuracy: 0.3500 - val_loss: 44.4787 - val_accuracy: 0.3750
# Epoch 12/50
# 30/30 [==============================] - 9s 295ms/step - loss: 1.0386 - accuracy: 0.4000 - val_loss: 28.8803 - val_accuracy: 0.3750
# Epoch 13/50
# 30/30 [==============================] - 9s 295ms/step - loss: 1.7512 - accuracy: 0.3667 - val_loss: 17.2007 - val_accuracy: 0.3750
# Epoch 14/50
# 30/30 [==============================] - 9s 292ms/step - loss: 1.1401 - accuracy: 0.4500 - val_loss: 14.9308 - val_accuracy: 0.1250
# Epoch 15/50
# 30/30 [==============================] - 9s 293ms/step - loss: 1.0291 - accuracy: 0.5333 - val_loss: 9.0416 - val_accuracy: 0.5000
# Epoch 16/50
# 30/30 [==============================] - 9s 296ms/step - loss: 0.9905 - accuracy: 0.5333 - val_loss: 9.2093 - val_accuracy: 0.5000
# Epoch 17/50
# 30/30 [==============================] - 9s 293ms/step - loss: 1.0793 - accuracy: 0.4833 - val_loss: 8.6691 - val_accuracy: 0.3750
# Epoch 18/50
# 30/30 [==============================] - 9s 296ms/step - loss: 0.9664 - accuracy: 0.5167 - val_loss: 7.9470 - val_accuracy: 0.1250
# Epoch 19/50
# 30/30 [==============================] - 9s 299ms/step - loss: 1.0365 - accuracy: 0.4667 - val_loss: 2.1625 - val_accuracy: 0.6250
# Epoch 20/50
# 30/30 [==============================] - 9s 296ms/step - loss: 1.0013 - accuracy: 0.4667 - val_loss: 1.7253 - val_accuracy: 0.3750
# Epoch 21/50
# 30/30 [==============================] - 9s 296ms/step - loss: 0.9698 - accuracy: 0.5167 - val_loss: 1.8270 - val_accuracy: 0.2500
# Epoch 22/50
# 30/30 [==============================] - 9s 287ms/step - loss: 0.9166 - accuracy: 0.5333 - val_loss: 0.8074 - val_accuracy: 0.5000
# Epoch 23/50
# 30/30 [==============================] - 9s 294ms/step - loss: 0.9269 - accuracy: 0.5833 - val_loss: 1.0258 - val_accuracy: 0.7500
# Epoch 24/50
# 30/30 [==============================] - 9s 293ms/step - loss: 0.8980 - accuracy: 0.5500 - val_loss: 0.9645 - val_accuracy: 0.3750
# Epoch 25/50
# 30/30 [==============================] - 9s 298ms/step - loss: 0.9490 - accuracy: 0.4833 - val_loss: 0.9126 - val_accuracy: 0.5000
# Epoch 26/50
# 30/30 [==============================] - 9s 292ms/step - loss: 0.9375 - accuracy: 0.5333 - val_loss: 0.7344 - val_accuracy: 0.6250
# Epoch 27/50
# 30/30 [==============================] - 9s 295ms/step - loss: 0.8917 - accuracy: 0.6000 - val_loss: 1.0329 - val_accuracy: 0.6250
# Epoch 28/50
# 30/30 [==============================] - 9s 292ms/step - loss: 0.8468 - accuracy: 0.5667 - val_loss: 0.5223 - val_accuracy: 0.8750
# Epoch 29/50
# 30/30 [==============================] - 9s 298ms/step - loss: 0.9203 - accuracy: 0.5667 - val_loss: 2.2612 - val_accuracy: 0.2500
# Epoch 30/50
# 30/30 [==============================] - 9s 295ms/step - loss: 1.4262 - accuracy: 0.4500 - val_loss: 1.9753 - val_accuracy: 0.1250
# Epoch 31/50
# 30/30 [==============================] - 9s 291ms/step - loss: 1.0342 - accuracy: 0.4667 - val_loss: 1.8801 - val_accuracy: 0.0000e+00
# Epoch 32/50
# 30/30 [==============================] - 9s 293ms/step - loss: 1.0258 - accuracy: 0.4833 - val_loss: 2.5838 - val_accuracy: 0.5000
# Epoch 33/50
# 30/30 [==============================] - 9s 292ms/step - loss: 0.9626 - accuracy: 0.4500 - val_loss: 4.5216 - val_accuracy: 0.2500
# Epoch 34/50
# 30/30 [==============================] - 9s 294ms/step - loss: 0.9071 - accuracy: 0.4833 - val_loss: 5.7902 - val_accuracy: 0.2500
# Epoch 35/50
# 30/30 [==============================] - 9s 294ms/step - loss: 0.8548 - accuracy: 0.5333 - val_loss: 2.6253 - val_accuracy: 0.2500
# Epoch 36/50
# 30/30 [==============================] - 9s 294ms/step - loss: 0.8640 - accuracy: 0.5833 - val_loss: 2.1176 - val_accuracy: 0.5000
# Epoch 37/50
# 30/30 [==============================] - 9s 297ms/step - loss: 0.8601 - accuracy: 0.5833 - val_loss: 3.5114 - val_accuracy: 0.5000
# Epoch 38/50
# 30/30 [==============================] - 9s 294ms/step - loss: 0.7905 - accuracy: 0.6333 - val_loss: 2.0111 - val_accuracy: 0.3750
# Epoch 39/50
# 30/30 [==============================] - 9s 292ms/step - loss: 0.7529 - accuracy: 0.5667 - val_loss: 2.2807 - val_accuracy: 0.6250
# Epoch 40/50
# 30/30 [==============================] - 9s 295ms/step - loss: 0.6135 - accuracy: 0.6000 - val_loss: 0.6450 - val_accuracy: 0.8750
# Epoch 41/50
# 30/30 [==============================] - 9s 293ms/step - loss: 0.7420 - accuracy: 0.5833 - val_loss: 2.6011 - val_accuracy: 0.2500
# Epoch 42/50
# 30/30 [==============================] - 9s 298ms/step - loss: 0.7386 - accuracy: 0.6000 - val_loss: 1.9002 - val_accuracy: 0.2500
# Epoch 43/50
# 30/30 [==============================] - 9s 291ms/step - loss: 0.7398 - accuracy: 0.6667 - val_loss: 0.9159 - val_accuracy: 0.1250
# Epoch 44/50
# 30/30 [==============================] - 9s 296ms/step - loss: 0.5332 - accuracy: 0.6500 - val_loss: 2.8632 - val_accuracy: 0.3750
# Epoch 45/50
# 30/30 [==============================] - 9s 294ms/step - loss: 0.5211 - accuracy: 0.6667 - val_loss: 2.3190 - val_accuracy: 0.5000
# Epoch 46/50
# 30/30 [==============================] - 9s 293ms/step - loss: 0.4862 - accuracy: 0.6833 - val_loss: 0.6254 - val_accuracy: 0.6250
# Epoch 47/50
# 30/30 [==============================] - 9s 290ms/step - loss: 0.4723 - accuracy: 0.6667 - val_loss: 0.4208 - val_accuracy: 0.7500
# Epoch 48/50
# 30/30 [==============================] - 9s 296ms/step - loss: 0.5449 - accuracy: 0.7167 - val_loss: 4.6159 - val_accuracy: 0.2500
# Epoch 49/50
# 30/30 [==============================] - 9s 291ms/step - loss: 0.4820 - accuracy: 0.7500 - val_loss: 1.5314 - val_accuracy: 0.7500
# Epoch 50/50
# 30/30 [==============================] - 9s 298ms/step - loss: 0.5233 - accuracy: 0.8000 - val_loss: 4.1835 - val_accuracy: 0.7500

# %% [markdown]
# ## Ploting Model

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)
plt.figure()

plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend(loc=0)

plt.show()

# %% [markdown]
# ## Test Upload

# %%
#fungsi untuk mendapatkan label indeks hasil deteksi
def get_class_string_from_index(index):
   for class_string, class_index in validation_generator.class_indices.items():
      if class_index == index:
         return class_string

# %%
uploaded = files.upload()
print(train_generator.class_indices) 
for fn in uploaded.keys():
 
  # predicting images
  path = fn
  img = image.load_img(path, target_size=(150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)
 
  images = np.vstack([x])
  classes = model.predict(images, batch_size=10)
  predicted_index = np.argmax(classes)
  print(get_class_string_from_index(predicted_index))
  print("Hasil Prediksi: " + get_class_string_from_index(predicted_index))
# Out:
#      <input type="file" id="files-1c44d673-e7ab-4c69-9ca0-36c1f71383cf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1c44d673-e7ab-4c69-9ca0-36c1f71383cf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving DSC_0513.jpg to DSC_0513 (2).jpg
# {'Bacterial leaf blight': 0, 'Brown spot': 1, 'Leaf smut': 2}
# Bacterial leaf blight
# Hasil Prediksi: Bacterial leaf blight

# %% [markdown]
# ## Hasil sementara
# model memiliki akurasi yang tidak begitu tinggi dan hasil upload hanya  memberikan label Bacterial leaf Blight

# %% [markdown]
# # Inception Layer

# %%
# !wget --no-check-certificate \
    https://storage.googleapis.com/mledu-datasets/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5 \
    -O /tmp/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
  
from tensorflow.keras.applications.inception_v3 import InceptionV3

local_weights_file = '/tmp/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5'

pre_trained_model = InceptionV3(input_shape = (150, 150, 3), 
                                include_top = False, 
                                weights = None)

pre_trained_model.load_weights(local_weights_file)

for layer in pre_trained_model.layers:
  layer.trainable = False
  
# pre_trained_model.summary()

last_layer = pre_trained_model.get_layer('mixed7')
print('last layer output shape: ', last_layer.output_shape)
last_output = last_layer.output
# Out:
# --2021-05-12 09:52:37--  https://storage.googleapis.com/mledu-datasets/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.253.62.128, 172.217.13.80, 172.253.115.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.253.62.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 87910968 (84M) [application/x-hdf]
# Saving to: ‘/tmp/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5’
#
# /tmp/inception_v3_w 100%[===================>]  83.84M   130MB/s    in 0.6s
#
# 2021-05-12 09:52:38 (130 MB/s) - ‘/tmp/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5’ saved [87910968/87910968]
#
# last layer output shape:  (None, 7, 7, 768)

# %%
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras import layers


x = layers.Flatten()(last_output)
x = layers.Dense(512, activation='relu')(x)
x = layers.Dropout(0.1)(x)
x = layers.Dense  (3, activation='softmax')(x)           

model = Model( pre_trained_model.input, x) 

# model.compile(optimizer = RMSprop(lr=0.0001), 
#               loss = 'binary_crossentropy', 
#               metrics = ['accuracy'])

# %% [markdown]
# ## Compile Model

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=tf.optimizers.Adam(),
              metrics=['accuracy'])

# %%
history = model.fit(
      train_generator,
      steps_per_epoch=30,  
      epochs=50,
      validation_data=validation_generator, 
      validation_steps=4, 
     )
# Out:
# Epoch 1/50
# 30/30 [==============================] - 7s 219ms/step - loss: 0.1854 - accuracy: 0.9667 - val_loss: 1.4736 - val_accuracy: 0.5000
# Epoch 2/50
# 30/30 [==============================] - 7s 217ms/step - loss: 0.2247 - accuracy: 0.9667 - val_loss: 0.0548 - val_accuracy: 1.0000
# Epoch 3/50
# 30/30 [==============================] - 7s 217ms/step - loss: 0.0204 - accuracy: 1.0000 - val_loss: 0.4266 - val_accuracy: 0.8750
# Epoch 4/50
# 30/30 [==============================] - 7s 217ms/step - loss: 0.0664 - accuracy: 0.9500 - val_loss: 0.8000 - val_accuracy: 0.7500
# Epoch 5/50
# 30/30 [==============================] - 7s 217ms/step - loss: 0.2905 - accuracy: 0.9167 - val_loss: 0.4510 - val_accuracy: 0.8750
# Epoch 6/50
# 30/30 [==============================] - 7s 215ms/step - loss: 0.4533 - accuracy: 0.9333 - val_loss: 1.3622 - val_accuracy: 0.7500
# Epoch 7/50
# 30/30 [==============================] - 7s 216ms/step - loss: 0.1103 - accuracy: 0.9667 - val_loss: 0.4863 - val_accuracy: 0.6250
# Epoch 8/50
# 30/30 [==============================] - 7s 215ms/step - loss: 0.0286 - accuracy: 0.9833 - val_loss: 0.2546 - val_accuracy: 0.8750
# Epoch 9/50
# 30/30 [==============================] - 7s 216ms/step - loss: 0.3435 - accuracy: 0.9333 - val_loss: 0.8036 - val_accuracy: 0.7500
# Epoch 10/50
# 30/30 [==============================] - 7s 218ms/step - loss: 0.0272 - accuracy: 0.9833 - val_loss: 0.6265 - val_accuracy: 0.8750
# Epoch 11/50
# 30/30 [==============================] - 6s 215ms/step - loss: 0.5986 - accuracy: 0.8833 - val_loss: 0.8196 - val_accuracy: 0.7500
# Epoch 12/50
# 30/30 [==============================] - 7s 218ms/step - loss: 0.8689 - accuracy: 0.9167 - val_loss: 0.5227 - val_accuracy: 0.7500
# Epoch 13/50
# 30/30 [==============================] - 6s 214ms/step - loss: 0.2379 - accuracy: 0.9500 - val_loss: 0.3874 - val_accuracy: 0.8750
# Epoch 14/50
# 30/30 [==============================] - 6s 214ms/step - loss: 0.2368 - accuracy: 0.9667 - val_loss: 1.3526 - val_accuracy: 0.8750
# Epoch 15/50
# 30/30 [==============================] - 6s 214ms/step - loss: 0.4116 - accuracy: 0.9500 - val_loss: 2.2656 - val_accuracy: 0.8750
# Epoch 16/50
# 30/30 [==============================] - 7s 217ms/step - loss: 0.0323 - accuracy: 0.9833 - val_loss: 0.8519 - val_accuracy: 0.7500
# Epoch 17/50
# 30/30 [==============================] - 7s 219ms/step - loss: 0.0144 - accuracy: 1.0000 - val_loss: 2.2429 - val_accuracy: 0.6250
# Epoch 18/50
# 30/30 [==============================] - 7s 215ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.7518 - val_accuracy: 0.8750
# Epoch 19/50
# 30/30 [==============================] - 7s 218ms/step - loss: 0.0556 - accuracy: 0.9667 - val_loss: 0.3799 - val_accuracy: 0.8750
# Epoch 20/50
# 30/30 [==============================] - 7s 217ms/step - loss: 0.2421 - accuracy: 0.9333 - val_loss: 0.3897 - val_accuracy: 0.8750
# Epoch 21/50
# 30/30 [==============================] - 7s 218ms/step - loss: 0.3275 - accuracy: 0.9167 - val_loss: 0.2999 - val_accuracy: 0.8750
# Epoch 22/50
# 30/30 [==============================] - 7s 219ms/step - loss: 0.0134 - accuracy: 1.0000 - val_loss: 0.7990 - val_accuracy: 0.8750
# Epoch 23/50
# 30/30 [==============================] - 7s 218ms/step - loss: 0.2089 - accuracy: 0.9667 - val_loss: 0.3516 - val_accuracy: 0.8750
# Epoch 24/50
# 30/30 [==============================] - 7s 218ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1039 - val_accuracy: 0.8750
# Epoch 25/50
# 30/30 [==============================] - 7s 217ms/step - loss: 1.4559e-04 - accuracy: 1.0000 - val_loss: 0.3692 - val_accuracy: 0.8750
# Epoch 26/50
# 30/30 [==============================] - 7s 217ms/step - loss: 7.2205e-04 - accuracy: 1.0000 - val_loss: 0.8987 - val_accuracy: 0.7500
# Epoch 27/50
# 30/30 [==============================] - 7s 218ms/step - loss: 3.6881e-05 - accuracy: 1.0000 - val_loss: 0.8859 - val_accuracy: 0.7500
# Epoch 28/50
# 30/30 [==============================] - 7s 219ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.4544 - val_accuracy: 0.8750
# Epoch 29/50
# 30/30 [==============================] - 7s 219ms/step - loss: 0.0148 - accuracy: 0.9833 - val_loss: 7.0579e-04 - val_accuracy: 1.0000
# Epoch 30/50
# 30/30 [==============================] - 7s 216ms/step - loss: 0.0579 - accuracy: 0.9833 - val_loss: 0.5449 - val_accuracy: 0.8750
# Epoch 31/50
# 30/30 [==============================] - 7s 217ms/step - loss: 0.1653 - accuracy: 0.9333 - val_loss: 0.0303 - val_accuracy: 1.0000
# Epoch 32/50
# 30/30 [==============================] - 7s 219ms/step - loss: 0.0257 - accuracy: 0.9833 - val_loss: 0.2292 - val_accuracy: 0.8750
# Epoch 33/50
# 30/30 [==============================] - 7s 216ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0444 - val_accuracy: 1.0000
# Epoch 34/50
# 30/30 [==============================] - 6s 211ms/step - loss: 2.2158e-04 - accuracy: 1.0000 - val_loss: 0.2858 - val_accuracy: 0.7500
# Epoch 35/50
# 30/30 [==============================] - 7s 215ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.0430 - val_accuracy: 1.0000
# Epoch 36/50
# 30/30 [==============================] - 6s 213ms/step - loss: 6.5992e-04 - accuracy: 1.0000 - val_loss: 0.1185 - val_accuracy: 1.0000
# Epoch 37/50
# 30/30 [==============================] - 7s 217ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.2748 - val_accuracy: 0.8750
# Epoch 38/50
# 30/30 [==============================] - 7s 217ms/step - loss: 7.9990e-04 - accuracy: 1.0000 - val_loss: 0.4361 - val_accuracy: 0.7500
# Epoch 39/50
# 30/30 [==============================] - 7s 217ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0714 - val_accuracy: 1.0000
# Epoch 40/50
# 30/30 [==============================] - 6s 213ms/step - loss: 0.0203 - accuracy: 1.0000 - val_loss: 0.2537 - val_accuracy: 0.8750
# Epoch 41/50
# 30/30 [==============================] - 7s 216ms/step - loss: 8.8429e-06 - accuracy: 1.0000 - val_loss: 0.0511 - val_accuracy: 1.0000
# Epoch 42/50
# 30/30 [==============================] - 7s 219ms/step - loss: 1.0318e-05 - accuracy: 1.0000 - val_loss: 0.0227 - val_accuracy: 1.0000
# Epoch 43/50
# 30/30 [==============================] - 7s 215ms/step - loss: 1.5952e-04 - accuracy: 1.0000 - val_loss: 0.0580 - val_accuracy: 1.0000
# Epoch 44/50
# 30/30 [==============================] - 6s 212ms/step - loss: 1.0113e-05 - accuracy: 1.0000 - val_loss: 0.0190 - val_accuracy: 1.0000
# Epoch 45/50
# 30/30 [==============================] - 7s 220ms/step - loss: 6.5591e-05 - accuracy: 1.0000 - val_loss: 0.0444 - val_accuracy: 1.0000
# Epoch 46/50
# 30/30 [==============================] - 7s 212ms/step - loss: 2.9067e-06 - accuracy: 1.0000 - val_loss: 0.2051 - val_accuracy: 0.8750
# Epoch 47/50
# 30/30 [==============================] - 7s 215ms/step - loss: 5.8204e-05 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 1.0000
# Epoch 48/50
# 30/30 [==============================] - 7s 217ms/step - loss: 1.3136e-04 - accuracy: 1.0000 - val_loss: 0.0598 - val_accuracy: 1.0000
# Epoch 49/50
# 30/30 [==============================] - 6s 211ms/step - loss: 2.6868e-04 - accuracy: 1.0000 - val_loss: 0.0562 - val_accuracy: 1.0000
# Epoch 50/50
# 30/30 [==============================] - 6s 214ms/step - loss: 1.1829e-04 - accuracy: 1.0000 - val_loss: 0.2039 - val_accuracy: 0.8750

# %% [markdown]
# ## Ploting Model

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)
plt.figure()

plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend(loc=0)

plt.show()

# %% [markdown]
# ## Test Upload

# %%
uploaded = files.upload()
print(train_generator.class_indices) 
for fn in uploaded.keys():
 
  # predicting images
  path = fn
  img = image.load_img(path, target_size=(150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)
 
  images = np.vstack([x])
  classes = model.predict(images, batch_size=10)
  predicted_index = np.argmax(classes)
  print(get_class_string_from_index(predicted_index))
  print("Hasil Prediksi: " + get_class_string_from_index(predicted_index))
# Out:
#      <input type="file" id="files-90f8b46c-58d1-4fe5-bcb9-360237693eee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-90f8b46c-58d1-4fe5-bcb9-360237693eee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving brownspot.jpg to brownspot (6).jpg
# {'Bacterial leaf blight': 0, 'Brown spot': 1, 'Leaf smut': 2}
# Brown spot
# Hasil Prediksi: Brown spot

# %% [markdown]
# ## Hasil sementara
# model memiliki akurasi yang tidak cukup tinggi dan hasil upload cenderung memberi prediksi leaf smut
